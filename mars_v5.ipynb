# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# !apt-get install -y aria2
# !pip install requests beautifulsoup4
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 3 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,513 kB in 0s (7,185 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 118252 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
import requests
from bs4 import BeautifulSoup

amc_urls = []
for i in range(1, 145):
    subj = str(i).zfill(2)
    url = f"http://mocap.cs.cmu.edu/subjects/{subj}/"
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    for link in soup.find_all("a"):
        href = link.get("href", "")
        if href.endswith(".amc"):
            amc_urls.append(f"http://mocap.cs.cmu.edu/subjects/{subj}/{href}")

print(f"Total .amc files found: {len(amc_urls)}")

# Download all in parallel
with open("amc_urls.txt", "w") as f:
    f.write("\n".join(amc_urls))

# !aria2c -i amc_urls.txt -j 16 -x 4 --dir="./amc_files"
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_22.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_11.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_19.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_23.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_24.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_25.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_26.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_28.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_30.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_29.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/32_10.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/32_15.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_31.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_32.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_33.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/35_34.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/36_01.amc
#
# 05/19 00:23:59 [NOTICE] Download complete: ./amc_files/32_20.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/31_09.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/31_10.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/32_11.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/32_12.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_04.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_10.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_02.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_09.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_11.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_08.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/35_27.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_03.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_18.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_20.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_21.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_16.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_07.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_17.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_19.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_26.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_27.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_05.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_06.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_28.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_23.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_22.amc
#
# 05/19 00:24:00 [NOTICE] Download complete: ./amc_files/36_24.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_25.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_13.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_14.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_12.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/38_01.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/38_02.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_32.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/37_01.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_01.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_02.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_03.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/38_03.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_15.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_33.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_29.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_31.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_05.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_06.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_30.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_04.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_08.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_07.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_09.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_14.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_11.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_34.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_35.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_37.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_10.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_13.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/36_36.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/39_12.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/38_04.amc
#
# 05/19 00:24:01 [NOTICE] Download complete: ./amc_files/40_02.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_05.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_09.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_06.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_07.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_06.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_08.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_10.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/42_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/43_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_11.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_02.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/43_03.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/43_02.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/45_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_03.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/46_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_07.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_04.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_09.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_04.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/47_01.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_07.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/41_03.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_03.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_08.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_10.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_13.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/40_11.amc
#
# 05/19 00:24:02 [NOTICE] Download complete: ./amc_files/49_05.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_02.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_06.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_14.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/41_08.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/41_05.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_10.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_12.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_11.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_15.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_17.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_20.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_16.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_19.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/41_04.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/40_12.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_01.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_09.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_08.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_18.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_10.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_06.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_04.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_21.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_05.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_13.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_07.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/49_22.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_18.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_17.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_14.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_15.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_09.amc
#
# 05/19 00:24:03 [NOTICE] Download complete: ./amc_files/54_03.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_22.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_01.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_04.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_25.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_26.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_02.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_12.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_19.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_23.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_16.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_02.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_24.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_05.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_27.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_11.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_10.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_20.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_12.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_08.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_03.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_07.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_16.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_11.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/54_21.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_09.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_25.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_21.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_22.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/56_01.amc
#
# 05/19 00:24:04 [NOTICE] Download complete: ./amc_files/55_06.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_14.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_20.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_17.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_19.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_18.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_26.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_24.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_02.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_23.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_27.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_13.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_01.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_03.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_02.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_15.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_05.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_06.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_08.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_07.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_10.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_03.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/55_28.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_11.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_04.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_12.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_09.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_13.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_08.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_06.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_14.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/56_05.amc
#
# 05/19 00:24:05 [NOTICE] Download complete: ./amc_files/60_15.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/60_04.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_01.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_02.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_05.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_06.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_07.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/62_02.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_09.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/56_07.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_08.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/62_03.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_15.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/62_05.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_03.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/62_07.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_10.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/61_04.amc
#
# 05/19 00:24:06 [NOTICE] Download complete: ./amc_files/62
# bc5d27|OK  |   9.4MiB/s|./amc_files/144_30.amc
# 366d22|OK  |    11MiB/s|./amc_files/144_33.amc
# 895cce|OK  |   8.1MiB/s|./amc_files/144_31.amc
# 781c9a|OK  |   8.1MiB/s|./amc_files/144_34.amc
# 48e2c8|OK  |   5.9MiB/s|./amc_files/144_32.amc
#
# Status Legend:
# (OK):download completed.

# %%
#parse the amc file
def parse_mocap(filepath: str) -> torch.Tensor:
    frames = []
    current = []

    for line in open(filepath):
        line = line.strip()
        if not line or line.startswith(":") or line.startswith("#"):
            continue
        if line.isdigit():
            if current:
                frames.append(current)
            current = []
        else:
            parts = line.split()
            current.extend(float(v) for v in parts[1:])

    if current:
        frames.append(current)

    max_len = max(len(f) for f in frames)
    frames = [f + [0.0]*(max_len-len(f)) for f in frames]

    return torch.tensor(frames) #returns a tensor of shape (n_frames, action_dim)

# %%
from multiprocessing import Pool
from pathlib import Path
import torch
import random

amc_files = sorted(Path("./amc_files").glob("*.amc"))

def safe_parse(filepath):
    try:
        tensor = parse_mocap(str(filepath))
        subject = filepath.name.split("_")[0]  # e.g. "01" from "01_02.amc"
        return (subject, tensor)
    except Exception as e:
        print(f"Skipped {filepath.name}: {e}")
        return None

with Pool() as pool:
    results = pool.map(safe_parse, amc_files)
results = [r for r in results if r is not None]

# Group clips by subject
from collections import defaultdict
subject_clips = defaultdict(list)
for subject, tensor in results:
    subject_clips[subject].append(tensor)

# Shuffle subjects
subjects = list(subject_clips.keys())
random.seed(42)
random.shuffle(subjects)

# 80/10/10 on subjects
n = len(subjects)
n_train = int(0.8 * n)
n_val   = int(0.1 * n)

train_subjects = subjects[:n_train]
val_subjects   = subjects[n_train:n_train + n_val]
test_subjects  = subjects[n_train + n_val:]

train = torch.cat([t for s in train_subjects for t in subject_clips[s]], dim=0)
val   = torch.cat([t for s in val_subjects   for t in subject_clips[s]], dim=0)
test  = torch.cat([t for s in test_subjects  for t in subject_clips[s]], dim=0)

print(f"Subjects — Train: {len(train_subjects)} | Val: {len(val_subjects)} | Test: {len(test_subjects)}")
print(f"Shapes   — Train: {train.shape} | Val: {val.shape} | Test: {test.shape}")

torch.save(train, "/content/drive/MyDrive/mocap_train_tensor.pt")
torch.save(val,   "/content/drive/MyDrive/mocap_val_tensor.pt")
torch.save(test,  "/content/drive/MyDrive/mocap_test_tensor.pt")
# Out:
# Subjects — Train: 88 | Val: 11 | Test: 12
# Shapes   — Train: torch.Size([3332074, 62]) | Val: torch.Size([486318, 62]) | Test: torch.Size([387414, 62])

# %%
#get the datasets
from google.colab import drive
drive.mount('/content/drive')

train_set = torch.load("/content/drive/MyDrive/mocap_train_tensor.pt")
val_set   = torch.load("/content/drive/MyDrive/mocap_val_tensor.pt")
test_set  = torch.load("/content/drive/MyDrive/mocap_test_tensor.pt")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_set = train_set.to(device)
val_set   = val_set.to(device)
test_set  = test_set.to(device)

print(train_set.shape, val_set.shape, test_set.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# torch.Size([3332074, 62]) torch.Size([486318, 62]) torch.Size([387414, 62])

# %%
#normalise the dataset
mean = train_set.mean(dim=0)
std  = train_set.std(dim=0) + 1e-8
train_set = (train_set-mean)/std
val_set = (val_set-mean)/std
test_set = (test_set-mean)/std

# %%
#hyperparameters
action_dim  = 62
d_model     = 256
num_heads   = 8
num_layers  = 10
max_seq     = 64 #sliding window
_batch_size  = 1024
_lr          = 1e-4

#encoder
class ActionEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.proj = nn.Linear(action_dim, d_model)

    def forward(self, x):
        # x shape: (batch, seq, action_dim)
        return self.proj(x)
        # output shape: (batch, seq, d_model)


#transformer block
class TransformerBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.attn  = nn.MultiheadAttention(d_model, num_heads, batch_first=True)
        self.ffn   = nn.Sequential(
            nn.Linear(d_model, d_model * 4),
            nn.GELU(),
            nn.Linear(d_model * 4, d_model)
        )

    def forward(self, x):
        normed = self.norm1(x)
        T = x.shape[1]
        mask = torch.nn.Transformer.generate_square_subsequent_mask(T).to(device)
        x = x + self.attn(normed, normed, normed, attn_mask=mask, is_causal=True)[0]
        x = x + self.ffn(self.norm2(x))

        return x

#decoder
class ActionDecoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.proj = nn.Linear(d_model, action_dim)

    def forward(self, x):
        # x shape: (batch, seq, d_model)
        return self.proj(x)
        # output shape: (batch, seq, action_dim)


#full unimodal model
class Mars(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = ActionEncoder()
        self.pos_emb = nn.Embedding(max_seq, d_model)
        self.blocks  = nn.ModuleList([TransformerBlock() for _ in range(num_layers)])
        self.decoder = ActionDecoder()

    def forward(self, x):
        # x shape: (batch, seq, action_dim)
        x = self.encoder(x)
        positions = torch.arange(x.shape[1], device=x.device)
        x = x + self.pos_emb(positions)
        for block in self.blocks:
            x = block(x)
        # decode last token, that's the next frame prediction
        x = self.decoder(x[:, -1, :])
        # output shape: (batch, action_dim)
        return x

model = Mars().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=_lr)
loss_fn = nn.MSELoss()

# %%
#lets train
def train_step(data, batch_size=_batch_size):
    max_start = data.shape[0] - max_seq - 1
    starts = torch.randint(0, max_start, (batch_size,))
    input  = torch.stack([data[s : s + max_seq] for s in starts])
    target = torch.stack([data[s + max_seq] for s in starts])
    pred   = model(input)
    loss   = loss_fn(pred, target)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss.item()

def train(data, val_data, n_steps=100):
    losses, val_losses = [], []
    for step in range(n_steps):
        loss = train_step(data)
        losses.append(loss)
        if step % 50 == 0:
            val_loss = test(val_data)
            val_losses.append((step, val_loss))
            print(f"step {step:6d}  train {loss:.6f}  val {val_loss:.6f}")
    return losses, val_losses

losses, val_losses = train(train_set, val_set, n_steps=1000)
# Out:
# step      0  train 1.818641  val 1.780286
# step     50  train 0.209971  val 0.438753
# step    100  train 0.078709  val 0.243366
# step    150  train 0.059459  val 0.122779
# step    200  train 0.040425  val 0.148529
# step    250  train 0.029609  val 0.051688
# step    300  train 0.016821  val 0.133223
# step    350  train 0.031956  val 0.047287
# step    400  train 0.016437  val 0.052785
# step    450  train 0.016682  val 0.123161
# step    500  train 0.010739  val 0.128946
# step    550  train 0.011361  val 0.052435
# step    600  train 0.006703  val 0.018875
# step    650  train 0.005670  val 0.066471
# step    700  train 0.005552  val 0.127051
# step    750  train 0.006193  val 0.082333
# step    800  train 0.007493  val 0.016917
# step    850  train 0.005823  val 0.015013
# step    900  train 0.005233  val 0.081696
# step    950  train 0.005547  val 0.022985

# %%
plt.plot(losses)

# %%
steps = [x[0] for x in val_losses]
vals  = [x[1] for x in val_losses]
plt.plot(steps, vals)
plt.xlabel('step')
plt.ylabel('val loss')
plt.title('validation loss')
plt.show()

# %%
#test
def test(seq, n_windows=500):
    model.eval()
    losses = []
    max_start = seq.shape[0] - max_seq - 1
    with torch.no_grad():
        for _ in range(n_windows):
            s = torch.randint(0, max_start, (1,)).item()
            input  = seq[s : s + max_seq].unsqueeze(0)
            target = seq[s + max_seq].unsqueeze(0)
            pred   = model(input)
            loss   = loss_fn(pred, target)
            losses.append(loss.item())
    model.train()
    return sum(losses) / len(losses)

# %%
print(f"test loss: {test(test_set, n_windows=500)}")
# Out:
# test loss: 0.3066933001348516

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/mars_v5.pt')

# %%
#real test
cartwheels        = (parse_mocap("/content/drive/MyDrive/test_datasets/cartwheels.amc ").to(device) - mean) / std
kicking           = (parse_mocap("/content/drive/MyDrive/test_datasets/kicking.amc ").to(device) - mean) / std
punching          = (parse_mocap("/content/drive/MyDrive/test_datasets/punching.amc").to(device) - mean) / std
range_of_motion   = (parse_mocap("/content/drive/MyDrive/test_datasets/range_of_motion.amc").to(device) - mean) / std
run_to_stop       = (parse_mocap("/content/drive/MyDrive/test_datasets/run_to_stop.amc").to(device) - mean) / std
walk_n_pickup     = (parse_mocap("/content/drive/MyDrive/test_datasets/walk_n_pickup.amc ").to(device) - mean) / std
walk_n_stepover   = (parse_mocap("/content/drive/MyDrive/test_datasets/walk_n_stepover.amc ").to(device) - mean) / std
waving            = (parse_mocap("/content/drive/MyDrive/test_datasets/waving.amc").to(device) - mean) / std
chicken_dance     = (parse_mocap("/content/drive/MyDrive/test_datasets/chicken_dance.amc ").to(device) - mean) / std

# %%
import torch

model = Mars().to(device)
model.load_state_dict(torch.load('/content/drive/MyDrive/mars_v5.pt'))
# Out:
# <All keys matched successfully>

# %%
print(f"cartwheels:        {test(cartwheels,        n_windows=500)}")
print(f"chicken_dance:     {test(chicken_dance,     n_windows=500)}")
print(f"kicking:           {test(kicking,           n_windows=500)}")
print(f"punching:          {test(punching,          n_windows=500)}")
print(f"range_of_motion:   {test(range_of_motion,   n_windows=500)}")
print(f"run_to_stop:       {test(run_to_stop,       n_windows=500)}")
print(f"walk_n_pickup:     {test(walk_n_pickup,     n_windows=500)}")
print(f"walk_n_stepover:   {test(walk_n_stepover,   n_windows=500)}")
print(f"waving:            {test(waving,            n_windows=500)}")
# Out:
# cartwheels:        0.14415358002029824
# chicken_dance:     0.0029490151579957455
# kicking:           0.0025335993624757977
# punching:          0.0032032455208245666
# range_of_motion:   0.08312530925963074
# run_to_stop:       0.003093965017935261
# walk_n_pickup:     0.0020897496169200165
# walk_n_stepover:   0.0019588632937520742
# waving:            0.0017569600115530193
